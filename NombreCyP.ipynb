# %%
print("""           
           J    AAA    V            V  IIIIIIIII     EEEEEEE   RRRR
           J  A     A   V          V        I        E        R    R
           J  A     A    V        V         I        E        R   R
           J  AAAAAAA     V      V          I        EEEEEEE  R R
     J     J  A     A      V    V           I        E        R  R
      J   J   A     A       V  V            I        E        R   R
        J     A     A        V          IIIIIIII     EEEEEEE  R     R""")
# Out:
#
#            J    AAA    V            V  IIIIIIIII     EEEEEEE   RRRR
#            J  A     A   V          V        I        E        R    R
#            J  A     A    V        V         I        E        R   R
#            J  AAAAAAA     V      V          I        EEEEEEE  R R
#      J     J  A     A      V    V           I        E        R  R
#       J   J   A     A       V  V            I        E        R   R
#         J     A     A        V          IIIIIIII     EEEEEEE  R     R
